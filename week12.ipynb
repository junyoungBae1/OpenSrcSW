# %%
import csv
f = open('seoul.csv','r', encoding = 'cp949')
data = csv.reader(f)
next(data)

minIndex = 0
maxIndex = 0
mx = 0
mn = 0
rangeGap = 0
date1 = ' '
date2 = ' '
date3 = ' '
for row in data:
    for i in range(3,5) : 
        row[i]= float(row[i])
    if mn > row[3] : 
        mn = row[3]
    if mx < row[4] :
        mx = row[4]
    if rangeGap < row[4]- row[3] :
        rangeGap = row[4] - row[3]
f.close()
f1 = open ('seoul.csv','r', encoding = 'cp949')
data = csv.reader(f1)
next(data)
for row in data :
    for i in range(3,5) :
        row[i] = float(row[i])
    if((row[4] - row[3]) == rangeGap) :
        date1 = row[0]
    if(row[3] == mn) :
        date2 = row[0]
    if(row[4] == mx) :
        date3 = row[0]
        
print('일교차가 가장 큰 날 : ',date1)
print('최저기온이 가장 낮은 날 : ',date2)
print('최고기온이 가장 높은 날 : ',date3)
f.close()
# Out:
# 일교차가 가장 큰 날 :  2021-04-21
# 최저기온이 가장 낮은 날 :  2021-01-08
# 최고기온이 가장 높은 날 :  2021-07-24

# %%
import csv 
f = open('subway.csv', 'r', encoding = 'cp949')
data = csv.reader(f)
next(data)

listm = []
name = '1호선'
result = ''
result2 = ''
result3 = ''
for row in data :
    for i in range(4,6) :
        row[i] = int(row[i].replace(',',""))
    if(name == row[1]) :
        station = row[3]
        num = row[4]+row[5]
        listm.append(num)
        
    if(name != row[1]) : #호선명
        
        listm.sort()
        print(name)
        print("이용객이 가장 많은 역 순위")
        
        f1 = open('subway.csv','r',encoding = 'cp949')
        data1 = csv.reader(f1)
        next(data1)
        for row1 in data1 :
            for i in range(4,6) :
                row1[i] = int(row1[i].replace(',',""))
            
            sum = row1[4]+row1[5]
            if(sum == listm[-1]):
                result1 = " 1. {0:s} ({1:d})".format(row1[3],listm[-1])
            if(sum == listm[-2]):
                result2 = "2. {0:s} ({1:d})".format(row1[3],listm[-2])
            if(sum == listm[-3]):
                result3 = "3. {0:s} ({1:d})".format(row1[3],listm[-3])
        print(result1,'\n',result2,'\n',result3,'\n')        
        f1.close()
        print("이용객이 가장 적은 역 순위")
        f2 = open('subway.csv','r',encoding = 'cp949')
        data2 = csv.reader(f2)
        next(data2)
        for row2 in data2 :
            for i in range(4,6) :
                row2[i] = int(row2[i].replace(',',""))
            
            sum = row2[4]+row2[5]
            if(sum == listm[0]):
                result1 = " 1. {0:s} ({1:d})".format(row2[3],listm[0])
            if(sum == listm[1]):
                result2 = "2. {0:s} ({1:d})".format(row2[3],listm[1])
            if(sum == listm[2]):
                result3 = "3. {0:s} ({1:d})".format(row2[3],listm[2])
        print(result1,'\n',result2,'\n',result3,'\n')        
        f2.close()
        
        listm = []
        num = row[4] + row[5]
        listm.append(num)
        name = row[1]
        
f.close()

print(name)
print("이용객이 가장 많은 역 순위")
        
f3 = open('subway.csv','r',encoding = 'cp949')
data3 = csv.reader(f3)
next(data3)
for row3 in data3 :
    for i in range(4,6) :
        row3[i] = int(row3[i].replace(',',""))
            
    sum = row3[4]+row3[5]
    if(sum == listm[-1]):
        result1 = " 1. {0:s} ({1:d})".format(row3[3],listm[-1])
    if(sum == listm[-2]):
        result2 = "2. {0:s} ({1:d})".format(row3[3],listm[-2])
    if(sum == listm[-3]):
        result3 = "3. {0:s} ({1:d})".format(row3[3],listm[-3])
print(result1,'\n',result2,'\n',result3,'\n')        
f3.close()
print("이용객이 가장 적은 역 순위")
f4 = open('subway.csv','r',encoding = 'cp949')
data4 = csv.reader(f4)
next(data4)
for row4 in data4 :
    for i in range(4,6) :
        row4[i] = int(row4[i].replace(',',""))
          
    sum = row4[4]+row4[5]
    if(sum == listm[0]):
        result1 = " 1. {0:s} ({1:d})".format(row4[3],listm[0])
    if(sum == listm[1]):
        result2 = "2. {0:s} ({1:d})".format(row4[3],listm[1])
    if(sum == listm[2]):
        result3 = "3. {0:s} ({1:d})".format(row4[3],listm[2])
print(result1,'\n',result2,'\n',result3,'\n')        
f4.close()
# Out:
# 1호선
# 이용객이 가장 많은 역 순위
#  1. 서울역 (2324817)
#  2. 종각 (1721553)
#  3. 종로3가 (1267098)
#
# 이용객이 가장 적은 역 순위
#  1. 동묘앞 (477540)
#  2. 동대문 (598363)
#  3. 신설동 (715381)
#
# 2호선
# 이용객이 가장 많은 역 순위
#  1. 강남 (4364436)
#  2. 잠실(송파구청) (3927922)
#  3. 신림 (3412199)
#
# 이용객이 가장 적은 역 순위
#  1. 도림천 (73495)
#  2. 신답 (92368)
#  3. 용두(동대문구청) (130447)
#
# 3호선
# 이용객이 가장 많은 역 순위
#  1. 고속터미널 (2393331)
#  2. 양재(서초구청) (2098334)
#  3. 연신내 (1933410)
#
# 이용객이 가장 적은 역 순위
#  1. 충무로 (24)
#  2. 학여울 (110564)
#  3. 무악재 (208517)
#
# 4호선
# 이용객이 가장 많은 역 순위
#  1. 수유(강북구청) (1852687)
#  2. 혜화 (1806760)
#  3. 쌍문 (1523740)
#
# 이용객이 가장 적은 역 순위
#  1. 남태령 (61860)
#  2. 동작(현충원) (78275)
#  3. 삼각지 (280235)
#
# 경부선
# 이용객이 가장 많은 역 순위
#  1. 영등포 (2256385)
#  2. 수원 (2081264)
#  3. 용산 (2032713)
#
# 이용객이 가장 적은 역 순위
#  1. 직산 (42371)
#  2. 서동탄 (72294)
#  3. 진위 (82663)
#
# 경인선
# 이용객이 가장 많은 역 순위
#  1. 부천 (1799939)
#  2. 부평 (1711637)
#  3. 역곡 (1445062)
#
# 이용객이 가장 적은 역 순위
#  1. 도원 (158971)
#  2. 인천 (165660)
#  3. 도화 (219427)
#
# 경원선
# ...
